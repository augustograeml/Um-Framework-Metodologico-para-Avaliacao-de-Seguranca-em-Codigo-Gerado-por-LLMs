# %%
from openai import OpenAI

# %%
client = OpenAI(api_key="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")

# %%
f = open("prompts.txt", "r")

# %%
response = client.chat.completions.create( model ="chatgpt-3.5-turbo", messages = {"role":"user", "content":})
# Out:
#   Cell In[6], line 1
#     response = client.chat.completions.create( model =)
#                                                ^
# SyntaxError: expected argument value expression
